# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv('../data/tb.csv', parse_dates=True)
# print ('Dataframe shape is {0}'.format(df.shape))
df.head()
# Out:
#        country iso2 iso3  iso_numeric g_whoregion  year  new_sp  new_sn  \
# 0  Afghanistan   AF  AFG            4         EMR  1980     NaN     NaN
# 1  Afghanistan   AF  AFG            4         EMR  1981     NaN     NaN
# 2  Afghanistan   AF  AFG            4         EMR  1982     NaN     NaN
# 3  Afghanistan   AF  AFG            4         EMR  1983     NaN     NaN
# 4  Afghanistan   AF  AFG            4         EMR  1984     NaN     NaN
#
#    new_su  new_ep   ...    conf_mdr_tx  conf_xdr_tx  hivtest  hivtest_pos  \
# 0     NaN     NaN   ...            NaN          NaN      NaN          NaN
# 1     NaN     NaN   ...            NaN          NaN      NaN          NaN
# 2     NaN     NaN   ...            NaN          NaN      NaN          NaN
# 3     NaN     NaN   ...            NaN          NaN      NaN          NaN
# 4     NaN     NaN   ...            NaN          NaN      NaN          NaN
#
#    hiv_cpt  hiv_art  hiv_reg  hiv_tbscr  hiv_ipt  hiv_reg_new
# ...

# %%
whoreg = df['g_whoregion']
list(sort(pd.unique(whoreg)))
# whoreg.unique() # does not work
# Out:
# ['AFR', 'AMR', 'EMR', 'EUR', 'SEA', 'WPR']

# %%
# dfc = df[df.notnull()].any()
dfs = df[['g_whoregion', 'country', 'year', 'new_sp', 'new_sn']]
dfs.columns = ['continent', 'country', 'year', 'sp', 'sn']

dfsc = dfs.dropna(subset = ['sp', 'sn'])  # exclude records with missing data
# dfsc.columns = ['continent', 'country', 'year', 'sp', 'sn']
print ('Nr of valid items:', len(dfsc))
dfsc.head()
# Out:
# Nr of valid items: 3566
#    continent      country  year    sp    sn
# 17       EMR  Afghanistan  1997   618   227
# 18       EMR  Afghanistan  1998  1833   489
# 19       EMR  Afghanistan  1999  1669   729
# 20       EMR  Afghanistan  2000  2892  2358
# 21       EMR  Afghanistan  2001  4639  2739

# %%
c = ['country']
cy = ['country', 'year']
data = dfsc[['country', 'year', 'sp', 'sn']].groupby(cy).agg(np.mean)
data.head(5)
# Out:
#                     sp    sn
# country     year
# Afghanistan 1997   618   227
#             1998  1833   489
#             1999  1669   729
#             2000  2892  2358
#             2001  4639  2739

# %%
# European data
europe = dfsc[dfsc.continent == 'EUR']
eurodata = europe[['country', 'year', 'sp']].groupby(['country', 'year']).agg(np.sum)
