# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
s = pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# 0     1
# 1     3
# 2     5
# 3   NaN
# 4     6
# 5     8
# dtype: float64

# %%
dates = pd.date_range('20130101', periods=6)
# dates
# pd.date_range()

# %%
df2 = pd.DataFrame({'A': 1,
                    'B': pd.Timestamp('20130102'),
                    'C': pd.Series(1, index = list(range(4)), dtype = 'float32'),
                    'D': np.array([3] * 4, dtype = 'uint32'),
                    'E': pd.Categorical(['test', 'train', 'test', 'train']),
                    'F': 'foo'})
# df2

# %%
df = pd.DataFrame(np.random.randn(6,4), index = dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.363854 -2.132378 -0.961892  1.513607
# 2013-01-02  0.263541 -1.669460 -0.139214 -0.244731
# 2013-01-03  1.262741 -2.214796  0.283240 -2.007134
# 2013-01-04  0.226193  0.148154 -1.595244 -1.563327
# 2013-01-05 -1.049434 -0.304288 -0.513492 -1.508466
# 2013-01-06 -0.227225 -0.849917  1.850699 -0.843099

# %%
# Sort by axis
# print df.sort_index(axis = 1, ascending=False)

#Sort by values
# df.sort(columns='B')

# df.sort(axis = 1, ascending=False)

# %%
# Selection by label
df.loc[dates[0], 'A']
# Out:
# 0.36385372171729824

# %%
# Selection by position
df.iloc[2,2]
# Out:
# 0.28324035973517692

# %%
# Boolean indexing
df2 = df.copy()
df2['E'] = ['one', 'one', 'two', 'three', 'two', 'three']
df2[df2.E.isin(['two'])]
# Out:
#                    A         B         C         D    E
# 2013-01-03  1.262741 -2.214796  0.283240 -2.007134  two
# 2013-01-05 -1.049434 -0.304288 -0.513492 -1.508466  two

# %%
s1 = pd.Series([1,2,3,4,5,6], index = pd.date_range('20130101', periods=6))
df['F'] = s1
df.at[dates[0], 'A'] = 0
df.iat[0,1] = 0
df.loc[:, 'D'] = 5 #np.array([5] * len(df))
# df[df < 0] = -df
df
# Out:
#                    A         B         C  D  F
# 2013-01-01  0.000000  0.000000 -0.961892  5  1
# 2013-01-02  0.263541 -1.669460 -0.139214  5  2
# 2013-01-03  1.262741 -2.214796  0.283240  5  3
# 2013-01-04  0.226193  0.148154 -1.595244  5  4
# 2013-01-05 -1.049434 -0.304288 -0.513492  5  5
# 2013-01-06 -0.227225 -0.849917  1.850699  5  6

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ['E'])
df1.loc[dates[0]:dates[1], 'E'] = 1
df1.fillna(value = 5)
pd.isnull(df1)
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False  False  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %%
df.mean(1)
# Out:
# 2013-01-01    1.007622
# 2013-01-02    1.090973
# 2013-01-03    1.466237
# 2013-01-04    1.555820
# 2013-01-05    1.626557
# 2013-01-06    2.354711
# Freq: D, dtype: float64

# %%
df
# Out:
#                    A         B         C  D  F
# 2013-01-01  0.000000  0.000000 -0.961892  5  1
# 2013-01-02  0.263541 -1.669460 -0.139214  5  2
# 2013-01-03  1.262741 -2.214796  0.283240  5  3
# 2013-01-04  0.226193  0.148154 -1.595244  5  4
# 2013-01-05 -1.049434 -0.304288 -0.513492  5  5
# 2013-01-06 -0.227225 -0.849917  1.850699  5  6

# %%
s = pd.Series([1,3,5,np.nan,6,8],index=dates).shift(2)
# df.sub(s, axis='index')
# df.index

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C   D   F
# 2013-01-01  0.000000  0.000000 -0.961892   5   1
# 2013-01-02  0.263541 -1.669460 -1.101106  10   3
# 2013-01-03  1.526282 -3.884257 -0.817865  15   6
# 2013-01-04  1.752475 -3.736103 -2.413109  20  10
# 2013-01-05  0.703041 -4.040391 -2.926601  25  15
# 2013-01-06  0.475816 -4.890309 -1.075902  30  21

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A    2.312176
# B    2.362950
# C    3.445943
# D    0.000000
# F    5.000000
# dtype: float64

# %%
s = pd.Series(np.random.randint(0,7,size=10))
s
# Out:
# 0    2
# 1    5
# 2    3
# 3    1
# 4    0
# 5    0
# 6    2
# 7    2
# 8    2
# 9    5
# dtype: int64

# %%
s.value_counts()
# Out:
# 2    4
# 5    2
# 0    2
# 3    1
# 1    1
# dtype: int64

# %%
s = pd.Series(['A', 'B', 'C', 'Aaba', 'Baca', np.nan, 'CABA', 'dog', 'cat'])
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
# MERGE section
df = pd.DataFrame(np.random.randn(10,4))
df
# Out:
#           0         1         2         3
# 0  1.598064 -0.644114 -1.699568 -0.266167
# 1  0.086871 -1.342486  0.128899 -0.248121
# 2 -0.914895 -0.577812  0.890671  0.347305
# 3 -0.426120 -0.983673  0.108785  1.548869
# 4  0.962945 -0.834158  0.682948  0.441350
# 5 -0.560985  0.283230 -2.314505 -0.633200
# 6 -0.906618  0.340191  0.600712  1.188002
# 7  0.034307 -0.097477 -0.939439 -0.235479
# 8  0.357522  0.133718  0.085120  0.446188
# 9  0.590465  1.232937 -1.404673  1.182028

# %%
pieces = [df[:3], df[3:7], df[7:]]
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0  1.598064 -0.644114 -1.699568 -0.266167
# 1  0.086871 -1.342486  0.128899 -0.248121
# 2 -0.914895 -0.577812  0.890671  0.347305
# 3 -0.426120 -0.983673  0.108785  1.548869
# 4  0.962945 -0.834158  0.682948  0.441350
# 5 -0.560985  0.283230 -2.314505 -0.633200
# 6 -0.906618  0.340191  0.600712  1.188002
# 7  0.034307 -0.097477 -0.939439 -0.235479
# 8  0.357522  0.133718  0.085120  0.446188
# 9  0.590465  1.232937 -1.404673  1.182028

# %%
left = pd.DataFrame({'key': ['foo', 'foo'], 'lval': [1,2]})
right = pd.DataFrame({'key': ['foo', 'foo'], 'rval': [4,5]})
# print left
# print right
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
df = pd.DataFrame(np.random.randn(8,4), columns=list('ABCD'))
df
# Out:
#           A         B         C         D
# 0  0.515218  0.461585 -0.506394 -0.764645
# 1 -0.702424  1.457457  1.033432  0.348197
# 2  0.217267  0.021835 -0.311404  0.368164
# 3  0.269039 -0.264924 -1.965072  0.359610
# 4 -1.114130 -0.554760  0.050883  0.596697
# 5  1.931413 -1.251363  0.596106 -0.726167
# 6  1.524316 -0.038574  1.752973  0.954356
# 7  0.889296  0.385485 -1.892329 -0.023919

# %%
s = df.iloc[3]
s
# Out:
# A    0.269039
# B   -0.264924
# C   -1.965072
# D    0.359610
# Name: 3, dtype: float64

# %%
df.append(s, ignore_index=True)
# Out:
#           A         B         C         D
# 0  0.515218  0.461585 -0.506394 -0.764645
# 1 -0.702424  1.457457  1.033432  0.348197
# 2  0.217267  0.021835 -0.311404  0.368164
# 3  0.269039 -0.264924 -1.965072  0.359610
# 4 -1.114130 -0.554760  0.050883  0.596697
# 5  1.931413 -1.251363  0.596106 -0.726167
# 6  1.524316 -0.038574  1.752973  0.954356
# 7  0.889296  0.385485 -1.892329 -0.023919
# 8  0.269039 -0.264924 -1.965072  0.359610

# %%
df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar',
   ....:                          'foo', 'bar', 'foo', 'foo'],
   ....:                    'B' : ['one', 'one', 'two', 'three',
   ....:                          'two', 'two', 'one', 'three'],
   ....:                    'C' : np.random.randn(8),
   ....:                    'D' : np.random.randn(8)})
df
# Out:
#      A      B         C         D
# 0  foo    one  1.335378 -0.838747
# 1  bar    one  0.970344  0.732836
# 2  foo    two -0.505537 -0.284794
# 3  bar  three -1.847766 -0.018857
# 4  foo    two -1.429763 -0.398184
# 5  bar    two  0.135625 -0.685323
# 6  foo    one  0.516185  1.046863
# 7  foo  three  0.236704  1.761078

# %%
df.groupby(['A', 'B']).sum()
# Out:
#                   C         D
# A   B
# bar one    0.970344  0.732836
#     three -1.847766 -0.018857
#     two    0.135625 -0.685323
# foo one    1.851563  0.208116
#     three  0.236704  1.761078
#     two   -1.935301 -0.682978

# %%
df = pd.DataFrame({"id":[1,2,3,4,5,6], "raw_grade":['a', 'b', 'b', 'a', 'a', 'e']})
df
# Out:
#    id raw_grade
# 0   1         a
# 1   2         b
# 2   3         b
# 3   4         a
# 4   5         a
# 5   6         e

# %%
# Make graphs prettier
pd.set_option('display.mpl_style', 'default')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-e4b75a334eed> in <module>()
#       1 # Make graphs prettier
#       2 pd.set_option('display.mpl_style', 'default')
# ----> 3 plt.figsize(15,5)
#
# AttributeError: 'module' object has no attribute 'figsize'

# %%
# Plotting
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2010', periods=1000))
ts = ts.cumsum()
ts.plot()
# ts

# %%
df = pd.DataFrame(np.random.randn(1000,4), index=ts.index, columns=list('ABCD'))
df.cumsum().plot()
